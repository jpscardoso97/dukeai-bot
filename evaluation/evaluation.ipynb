# %%
import pandas as pd

# %%
test_data = pd.read_json('test_qna.json', orient='records')

# %%
test_data
# Out:
#                                              question  \
# 0   What is the difference between the Machine Lea...
# 1   What is the purpose of the MENG 570 course in ...
# 2   Can students in the online Master of Engineeri...
# 3   What is the purpose of the EGR 590 Career Stra...
# 4   Can credits from the Graduate Certificate prog...
# 5   What are some of the industry partners that co...
# 6   How does the program support international stu...
# 7   What is the role of the MENG 551 course in the...
# 8   Can students in the Master of Engineering prog...
# 9   What type of support is available for students...
# 10  How do the on-campus and online Master of Engi...
# 11  What is the purpose of the AIPI 503 Python & D...
# 12  Can students in the Master of Engineering prog...
# 13  How does the program support the professional ...
# 14  What are the opportunities for Duke undergradu...
#
#                                                answer  \
# ...
